# %%
# To initialize a sympy session with common imports
from sympy import init_session
init_session()
# Out:
# IPython console for SymPy 1.14.0 (Python 3.14.0-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.14.0/

# %%
x, y = symbols('x y', positive=True)
a, b = symbols('a b', real=True)
z, t, c = symbols('z t c')

# %% [markdown]
# ### Powers and Exponents simplification functions
# #### powsimp() To simplify expressions involving powers and exponents

# %%
powsimp(x**a*x**b)
# Out:
#  a + b
# x

# %%
powsimp(x**a*y**a)
# Out:
#      a
# (x⋅y)

# %%
powsimp(t**c*z**c) # Will not simplify because t and z are not known to be positive, like in the case of imaginary numbers.
# Out:
#  c  c
# t ⋅z

# %%
powsimp(t**c*z**c, force=True) # Force the simplification regardless of assumptions
# Out:
#      c
# (t⋅z)

# %% [markdown]
# #### expand_power_exp / expand_power_base

# %%
expand_power_exp(x**(a + b))
# Out:
#  a  b
# x ⋅x

# %%
expand_power_base((x*y)**a)
# Out:
#  a  a
# x ⋅y

# %%
expand_power_base((z*t)**c) # Will not expand because z and t are not known to be positive, like in the case of imaginary numbers.
# Out:
#      c
# (t⋅z)

# %% [markdown]
# #### powdenest

# %%
powdenest((x**a)**b)
# Out:
#  a⋅b
# x

# %%
powdenest((z**a)**b) # Will not denest because z is not known to be positive, like in the case of imaginary numbers but can be overridden with the force=True option.
# Out:
#     b
# ⎛ a⎞
# ⎝z ⎠

# %% [markdown]
# #### Exponentials and logarithms

# %%
ln(x)  # In sympy ln is the natural logarithm (base e)
# Out:
# log(x)

# %%
print(expand_log(log(x*y)))
print(expand_log(log(x/y)))
print(expand_log(log(x**2)))
print(expand_log(log(x**n)))
print(expand_log(log(z*t)))
# Out:
# log(x) + log(y)
# log(x) - log(y)
# 2*log(x)
# n*log(x)
# log(t*z)

# %%
print(expand_log(log(z**2)))  # Will not expand because z is not known to be positive, like in the case of imaginary numbers but can be overridden with the force=True option.
print(expand_log(log(z**2), force=True))
# Out:
# log(z**2)
# 2*log(z)

# %%
print(logcombine(log(x) + log(y)))
print(logcombine(n*log(x)))
print(logcombine(n*log(z))) # Will not combine because z is not known to be positive, like in the case of imaginary numbers but can be overridden with the force=True option.
# Out:
# log(x*y)
# log(x**n)
# n*log(z)

# %%
logcombine(n*log(z), force=True)
# Out:
#    ⎛ n⎞
# log⎝z ⎠
