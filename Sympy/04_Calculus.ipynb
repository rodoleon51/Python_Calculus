# %%
# To initialize a sympy session with common imports
from sympy import *
init_session(use_unicode=True) # For pretty printing
# Out:
# IPython console for SymPy 1.14.0 (Python 3.14.0-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.14.0/

# %% [markdown]
# ### Derivatives

# %%
diff(cos(x), x)
# Out:
# -sin(x)

# %%
diff(exp(x**2), x)
# Out:
#      ⎛ 2⎞
#      ⎝x ⎠
# 2⋅x⋅ℯ

# %%
diff(x**4, x, x, x)
# Out:
# 24⋅x

# %%
diff(x**4, x, x, x)
# Out:
# 24⋅x

# %%
diff(x**4, x, 3)
# Out:
# 24⋅x

# %%
expr = exp(x*y*z)
diff(expr, x, y, y, z, z, z, z)
# Out:
#  3  2 ⎛ 3  3  3       2  2  2                ⎞  x⋅y⋅z
# x ⋅y ⋅⎝x ⋅y ⋅z  + 14⋅x ⋅y ⋅z  + 52⋅x⋅y⋅z + 48⎠⋅ℯ

# %%
diff(expr, x, y, 2, z, 4)
# Out:
#  3  2 ⎛ 3  3  3       2  2  2                ⎞  x⋅y⋅z
# x ⋅y ⋅⎝x ⋅y ⋅z  + 14⋅x ⋅y ⋅z  + 52⋅x⋅y⋅z + 48⎠⋅ℯ

# %%
diff(expr, x, y, y, z, 4)
# Out:
#  3  2 ⎛ 3  3  3       2  2  2                ⎞  x⋅y⋅z
# x ⋅y ⋅⎝x ⋅y ⋅z  + 14⋅x ⋅y ⋅z  + 52⋅x⋅y⋅z + 48⎠⋅ℯ

# %%
expr.diff(x, y, y, z, 4) # Called as a method of the expression. Same as above.
# Out:
#  3  2 ⎛ 3  3  3       2  2  2                ⎞  x⋅y⋅z
# x ⋅y ⋅⎝x ⋅y ⋅z  + 14⋅x ⋅y ⋅z  + 52⋅x⋅y⋅z + 48⎠⋅ℯ

# %%
deriv = Derivative(expr, x, y, y, z, 4) # Unevaluated derivative
deriv
# Out:
#      7
#     ∂     ⎛ x⋅y⋅z⎞
# ──────────⎝ℯ     ⎠
#   4   2
# ∂z  ∂y  ∂x

# %%
deriv.doit() # Evaluate the derivative
# Out:
#  3  2 ⎛ 3  3  3       2  2  2                ⎞  x⋅y⋅z
# x ⋅y ⋅⎝x ⋅y ⋅z  + 14⋅x ⋅y ⋅z  + 52⋅x⋅y⋅z + 48⎠⋅ℯ

# %% [markdown]
# ### Integrals

# %%
integrate(cos(x), x)
# Out:
# sin(x)

# %%
integrate(exp(-x), (x, 0, oo)) # arguments (integration_variable, lower_limit, upper_limit).
# Out:
# 1

# %%
integrate(exp(-x**2 - y**2), (x, -oo, oo), (y, -oo, oo))
# Out:
# π

# %%
expr = Integral(log(x)**2, x) # To return an unevaluated integral
expr
# Out:
# ⌠
# ⎮    2
# ⎮ log (x) dx
# ⌡

# %%
expr.doit() # To evaluate the integral
# Out:
#      2
# x⋅log (x) - 2⋅x⋅log(x) + 2⋅x

# %%
integ = Integral((x**4 + x**2*exp(x) - x**2 - 2*x*exp(x) - 2*x -
    exp(x))*exp(x)/((x - 1)**2*(x + 1)**2*(exp(x) + 1)), x)
integ
# Out:
# ⌠
# ⎮ ⎛ 4    2  x    2        x          x⎞  x
# ⎮ ⎝x  + x ⋅ℯ  - x  - 2⋅x⋅ℯ  - 2⋅x - ℯ ⎠⋅ℯ
# ⎮ ──────────────────────────────────────── dx
# ⎮               2        2 ⎛ x    ⎞
# ⎮        (x - 1) ⋅(x + 1) ⋅⎝ℯ  + 1⎠
# ⌡

# %%
integ.doit()
# Out:
#                  x
#    ⎛ x    ⎞     ℯ
# log⎝ℯ  + 1⎠ + ──────
#                2
#               x  - 1

# %%
integ = Integral(sin(x**2), x)
integ
integ.doit()
# Out:
#          ⎛√2⋅x⎞
# 3⋅√2⋅√π⋅S⎜────⎟⋅Γ(3/4)
#          ⎝ √π ⎠
# ──────────────────────
#        8⋅Γ(7/4)

# %%
integ = Integral(x**y*exp(-x), (x, 0, oo))
integ
# Out:
# ∞
# ⌠
# ⎮  y  -x
# ⎮ x ⋅ℯ   dx
# ⌡
# 0

# %%
integ.doit()
# Out:
# ⎧ Γ(y + 1)    for re(y) > -1
# ⎪
# ⎪∞
# ⎪⌠
# ⎨⎮  y  -x
# ⎪⎮ x ⋅ℯ   dx    otherwise
# ⎪⌡
# ⎪0
# ⎩

# %% [markdown]
# ### Numeric Integration

# %% [markdown]
# ### Limits

# %% [markdown]
# ### Series Expansion

# %% [markdown]
# ### Finite differences
