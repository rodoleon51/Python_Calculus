# %%
# For pretty printing of sympy expressions
from sympy import init_printing
init_printing()

# %%
# To initialize a sympy session with common imports
from sympy import init_session
init_session()
# Out:
# IPython console for SymPy 1.14.0 (Python 3.14.0-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.14.0/

# %%
# Example
Integral(sqrt(1/x), x)
# Out:
# ⌠
# ⎮     ___
# ⎮    ╱ 1
# ⎮   ╱  ─  dx
# ⎮ ╲╱   x
# ⌡

# %% [markdown]
# ## Printing Functions

# %%
# str() to get a string form of representation
from sympy import *
x, y, z = symbols('x y z')
str(Integral(sqrt(1/x), x))
# Out:
# 'Integral(sqrt(1/x), x)'

# %%
print(Integral(sqrt(1/x), x))
# Out:
# Integral(sqrt(1/x), x)

# %%
# srepr To show exact form of an expression
srepr(Integral(sqrt(1/x), x))
# Out:
# "Integral(Pow(Pow(Symbol('x'), Integer(-1)), Rational(1, 2)), Tuple(Symbol('x')))"

# %%
# To get the LaTeX form of an expression, use latex().
print(latex(Integral(sqrt(1/x), x)))
# Out:
# \int \sqrt{\frac{1}{x}}\, dx
